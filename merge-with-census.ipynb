# %% [markdown]
# # Notebook Title

# %% [markdown]
# ## Setup Python and R environment
# you can ignore this section

# %%
# %load_ext rpy2.ipython
# %load_ext autoreload
# %autoreload 2

# %matplotlib inline  
from matplotlib import rcParams
rcParams['figure.figsize'] = (16, 100)

import warnings
from rpy2.rinterface import RRuntimeWarning
warnings.filterwarnings("ignore") # Ignore all warnings
# warnings.filterwarnings("ignore", category=RRuntimeWarning) # Show some warnings

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display, HTML
# Out:
# Durante la inicialización - Warning messages:
# 1: Setting LC_COLLATE failed, using "C"
# 2: Setting LC_TIME failed, using "C"
# 3: Setting LC_MESSAGES failed, using "C"
# 4: Setting LC_MONETARY failed, using "C"

# %%
# %%javascript
# // Disable auto-scrolling
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %%
# %%R
#
# # My commonly used R imports
#
# require('tidyverse')
# require('tidycensus')
# Out:
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.4     ✔ readr     2.1.5
# ✔ forcats   1.0.0     ✔ stringr   1.5.1
# ✔ ggplot2   3.4.4     ✔ tibble    3.2.1
# ✔ lubridate 1.9.3     ✔ tidyr     1.3.1
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Loading required package: tidyverse
# Loading required package: tidycensus

# %% [markdown]
# ## Load & Clean Data
#
# 👉 Load the data along with the census connectors below (the output of the `connect-to-census.ipynb` notebook) and do any cleanup you'd like to do.

# %%
# %%R
# # Read the CSV file with custom delimiters
# df <- read.csv('Prueba1.csv')
# df
# Out:
#                                                                Name.STATE.COUNTY.TRACT.GEOID
# 1                                              100% Playground;36.0;47.0;97400.0;364797400.0
# 2                                          174th Street Playground;36.0;5.0;6200.0;3656200.0
# 3                                          227 Street Playground;36.0;5.0;40600.0;36540600.0
# 4                                                  Abe Lincoln;36.0;61.0;16900.0;366116900.0
# 5                                               Abigail Playground;36.0;5.0;7900.0;3657900.0
# 6                                       Agnes Haywood Playground;36.0;5.0;39000.0;36539000.0
# 7                                               Albemarle Park;36.0;47.0;49800.0;364749800.0
# 8                                  Albert J. Parham Playground;36.0;47.0;31300.0;364731300.0
# 9
#                               Alexander Hamilton Playground;36.0;61.0;25900.0;366125900.0
# 10                                          Alfred E. Smith Park;36.0;61.0;2500.0;36612500.0
# 11                                     Alice Kornegay Triangle;36.0;61.0;24200.0;366124200.0
# 12                                           Allerton Playground;36.0;5.0;31800.0;36531800.0
# 13                                       Alley Park (PS 213);36.0;81.0;137700.0;3681137700.0
# 14                                           Alley Pond Park;36.0;81.0;128300.0;3681128300.0
# 15                    Alley Pond Park (Alley Athletic Field);36.0;81.0;156700.0;3681156700.0
# 16                       Alley Pond Park (Alley Pond Spring);36.0;81.0;137700.0;3681137700.0
# 17                      Alley Pond Park (Horatio Playground);36.0;81.0;138501.0;3681138501.0
# 18                                          Alstyne Playground;36.0;81.0;41300.0;368141300.0
# 19                                         American Playground;36.0;47.0;56500.0;364756500.0
# 20                                     Ampere Playground (PS 64);36.0;81.0;4200.0;36814200.0
# 21                                              Andrews Playground;36.0;81.0;701.0;3681701.0
# 22                               Annandale Playground (PS 175);36.0;81.0;72100.0;368172100.0
# 23                                           Annunciation Park;36.0;61.0;21703.0;366121703.0
# 24                                            Arcilla Playground;36.0;5.0;17500.0;36517500.0
# 25                                           Arrochar Playground;36.0;85.0;2002.0;36852002.0
# 26                                        Arrow Community Garden;36.0;81.0;5700.0;36815700.0
# 27                                                    Asser Levy;36.0;61.0;6200.0;36616200.0
# 28                                             Asser Levy Park;36.0;47.0;35602.0;364735602.0
# 29                         Asser Levy Park (Performance Space);36.0;47.0;35602.0;364735602.0
# 30                                  Astoria Heights Playground;36.0;81.0;14500.0;368114500.0
# 31                           Astoria Park (Charybdis Playground);36.0;81.0;9900.0;36819900.0
# 32                                             Athens Sq (PS 17);36.0;81.0;7100.0;36817100.0
# 33                                      Aubondale Playground;36.0;81.0;120701.0;3681120701.0
# 34                                          Audubon Playground;36.0;61.0;25300.0;366125300.0
# 35                                          Augustus St. Gaudens;36.0;61.0;6400.0;36616400.0
# 36                                             Bailey Playground;36.0;5.0;28300.0;36528300.0
# 37                                           Baisley Pond Park;36.0;81.0;28803.0;368128803.0
# 38                                           Baisley Pond Park;36.0;81.0;30600.0;368130600.0
# 39                 Baisley Pond Park (157th Street Playground);36.0;81.0;27600.0;368127600.0
# 40                                         Bartlett Playground;36.0;47.0;50700.0;364750700.0
# 41                                Battery Park (Battery Gardens);36.0;61.0;1300.0;36611300.0
# 42                                  Battery Park Comfort Station;36.0;61.0;1300.0;36611300.0
# 43                             Bay Terrace Playground (PS 169);36.0;81.0;99704.0;368199704.0
# 44                                            Bayside Fields;36.0;81.0;108500.0;3681108500.0
# 45                                Bayside Playground (JHS 180);36.0;81.0;93800.0;368193800.0
# 46                                        Bayview Playground;36.0;47.0;103401.0;3647103401.0
# 47                                          Bedford Playground;36.0;47.0;51700.0;364751700.0
# 48                                            Behagen Playground;36.0;5.0;13100.0;36513100.0
# 49                                         Bellaire Playground;36.0;81.0;49202.0;368149202.0
# 50                                            Belmont Playground;36.0;5.0;37300.0;36537300.0
# 51                                         Bendheim Playground;36.0;61.0;14300.0;366114300.0
# 52                                                Bennett Park;36.0;61.0;27300.0;366127300.0
# 53                                           Benson Playground;36.0;47.0;28400.0;364728400.0
# 54                                            Bensonhurst Park;36.0;47.0;17000.0;364717000.0
# 55                                       Betsy Head Playground;36.0;47.0;90200.0;364790200.0
# 56             Betsy Head Playground (Administration Building);36.0;47.0;90200.0;364790200.0
# 57                                               Big Bush Park;36.0;47.0;47700.0;364747700.0
# 58                                        Bildersee Playground;36.0;47.0;31300.0;364731300.0
# 59                              Bill Brown Memorial Playground;36.0;47.0;59402.0;364759402.0
# 60                                           Bleecker Playground;36.0;61.0;7700.0;36617700.0
# 61                 Blood Root Valley (Greenbelt Nature Center);36.0;85.0;27704.0;368527704.0
# 62                              Blood Root Valley (Park House);36.0;85.0;27704.0;368527704.0
# 63                                           Bloomingdale Park;36.0;85.0;20803.0;368520803.0
# 64                                     Bloomingdale Playground;36.0;61.0;18900.0;366118900.0
# 65                    Blue Heron Park Preserve (Nature Center);36.0;85.0;17600.0;368517600.0
# 66                                                Bowne Park;36.0;81.0;104700.0;3681104700.0
# 67                                            Bowne Playground;36.0;81.0;85300.0;368185300.0
# 68                                           Breininger Park;36.0;81.0;162100.0;3681162100.0
# 69                                        Breukelen Playground;36.0;47.0;98200.0;364798200.0
# 70                                         Brevoort Playground;36.0;47.0;37900.0;364737900.0
# 71                                                 Bridge Park 2;36.0;47.0;2100.0;36472100.0
# 72                                              Broadway Malls;36.0;61.0;19702.0;366119702.0
# 73                            Bronx Park (Ben Abrams Playground);36.0;5.0;22401.0;36522401.0
# 74                                 Bronx Park (Brady Playground);36.0;5.0;23000.0;36523000.0
# 75                      Bronx Park (French Charley's Playground);36.0;5.0;41300.0;36541300.0
# 76                             Bronx Park (Olinville Playground);36.0;5.0;39600.0;36539600.0
# 77                                          Bronx Park (Ranaqua);36.0;5.0;33400.0;36533400.0
# 78                            Bronx Park (River Park Playground);36.0;5.0;36100.0;36536100.0
# 79                              Bronx Park (Rosewood Playground);36.0;5.0;33400.0;36533400.0
# 80                                Bronx Park (Waring Playground);36.0;5.0;33201.0;36533201.0
# 81                     Bronx River Parkway (Parque de los Ninos);36.0;5.0;33400.0;36533400.0
# 82                                             Brookville Park;36.0;81.0;65402.0;368165402.0
# 83                                                 Brower Park;36.0;47.0;33702.0;364733702.0
# 84                                        Brower Park (Museum);36.0;47.0;33702.0;364733702.0
# 85                                      Brownsville Playground;36.0;47.0;92000.0;364792000.0
# 86                                             Bufano Playground;36.0;5.0;18400.0;36518400.0
# 87                                  Bushwick Playground & Pool;36.0;47.0;39100.0;364739100.0
# 88                                  Bushwick Playground & Pool;36.0;47.0;39500.0;364739500.0
# 89                             Cabbell Park/Cambria Playground;36.0;81.0;61000.0;368161000.0
# 90                          Cadman Plaza & Brooklyn War Memorial;36.0;47.0;1300.0;36471300.0
# 91                          Cadman Plaza & Brooklyn War Memorial;36.0;47.0;1300.0;36471300.0
# 92                                           Campiz Playground;36.0;81.0;60300.0;368160300.0
# 93                                             Canarsie Park;36.0;47.0;102802.0;3647102802.0
# 94                                         Capt. Rivera Playground;36.0;5.0;7700.0;3657700.0
# 95                                            Capt. Tilly Park;36.0;81.0;45400.0;368145400.0
# 96                                  Captain Mario Fajardo Park;36.0;81.0;83700.0;368183700.0
# 97                                            Carl Schurz Park;36.0;61.0;13604.0;366113604.0
# 98                                       Carl Schurz Promenade;36.0;61.0;15401.0;366115401.0
# 99                                     Carmansville Playground;36.0;61.0;23700.0;366123700.0
# 100                                                 Carroll Park;36.0;47.0;5302.0;36475302.0
# 101                                          Carver Playground;36.0;47.0;37900.0;364737900.0
# 102                                           Caserta Playground;36.0;5.0;22200.0;36522200.0
# 103                                       Castle Hill Playground;36.0;5.0;22200.0;36522200.0
# 104                           Castlewood Playground (PS 186);36.0;81.0;155103.0;3681155103.0
# 105                                         Cauldwell Playground;36.0;5.0;14100.0;36514100.0
# 106             Cavanaugh Triangle (Angelo Campanero Playground);6.0;45.0;10100.0;64510100.0
# 107                                             Cedar Playground;36.0;5.0;18900.0;36518900.0
# 108                          Central Park (Ancient Playground);36.0;61.0;14300.0;366114300.0
# 109                                     Central Park (Arsenal);36.0;61.0;12200.0;366112200.0
# 110                            Central Park (Bethesda Terrace);36.0;61.0;23200.0;366123200.0
# 111                         Central Park (Conservatory Garden);36.0;61.0;17200.0;366117200.0
# 112                       Central Park (Dana Discovery Center);36.0;61.0;22400.0;366122400.0
# 113                        Central Park (Heckscher Playground);36.0;61.0;11000.0;366111000.0
# 114                             Central Park (Kerbs Boathouse);36.0;61.0;14300.0;366114300.0
# 115                                      Central Park (Lasker);36.0;61.0;19300.0;366119300.0
# 116                              Central Park (Loeb Boathouse);36.0;61.0;13400.0;366113400.0
# 117              Central Park (North Meadow Recreation Center);36.0;61.0;16002.0;366116002.0
# 118                                      Central Park (Ramble);36.0;61.0;21600.0;366121600.0
# 119                                 Central Park (Sheep Meadow;36.0;61.0;12200.0;366112200.0
# 120                         Central Park (Tavern on The Green);36.0;61.0;21600.0;366121600.0
# 121                               Central Park (Tennis Courts);36.0;61.0;15801.0;366115801.0
# 122                              Central Park (The Great Hill);36.0;61.0;19300.0;366119300.0
# 123              Central Park (The Metropolitan Museum of Art);36.0;61.0;14300.0;366114300.0
# 124                                   Central Park (West 61st);36.0;61.0;14300.0;366114300.0
# 125                                  Central Park (Wollman Rink);36.0;61.0;2602.0;36612602.0
# 126                     Central Park Delacorte Comfort Station;36.0;61.0;14000.0;366114000.0
# 127                                         Century Playground;36.0;47.0;36002.0;364736002.0
# 128      Challenge Playground (PS 187) 251 Street Playground;36.0;81.0;152902.0;3681152902.0
# 129                                                 Chelsea Park;36.0;61.0;5800.0;36615800.0
# 130                                    Chelsea Recreation Center;36.0;61.0;9901.0;36619901.0
# 131                        Cherry Tree (Washington) Playground;36.0;61.0;16600.0;366116600.0
# 132                                         Chester Playground;36.0;47.0;92400.0;364792400.0
# 133                                    Ciccarone Park Playground;36.0;5.0;38900.0;36538900.0
# 134                                           City Line Park;36.0;47.0;119200.0;3647119200.0
# 135                                               Claremont Park;36.0;5.0;22703.0;36522703.0
# 136                                    Claremont Park Playground;36.0;5.0;22500.0;36522500.0
# 137                                               Clark Playground;36.0;5.0;5100.0;3655100.0
# 138                                   Clement Clark Moore Park;36.0;61.0;17100.0;366117100.0
# 139                        Clintonville Playground (JHS 194);36.0;81.0;102900.0;3681102900.0
# 140                              Col. Charles Young Playground;36.0;61.0;21400.0;366121400.0
# 141                      Col. David Marcus Memorial Playground;36.0;47.0;43800.0;364743800.0
# 142                                      Coleman Square Playground;36.0;61.0;600.0;3661600.0
# 143                                         College Point Park;36.0;81.0;90700.0;368190700.0
# 144                                           Colucci Playground;36.0;5.0;30000.0;36530000.0
# 145                                                Columbus Park;36.0;47.0;1100.0;36471100.0
# 146                                                Columbus Park;36.0;61.0;3100.0;36613100.0
# 147                          Com. John Barry Park & Playground;36.0;47.0;48500.0;364748500.0
# 148                          Com. John Barry Park & Playground;36.0;47.0;48500.0;364748500.0
# 149          Com. John Barry Park & Playground (Athletic Area);36.0;47.0;48500.0;364748500.0
# 150                       Comm. Eugene S. Sarsfield Playground;36.0;47.0;73800.0;364773800.0
# 151                                               Coney Island;36.0;47.0;36200.0;364736200.0
# 152                                               Coney Island;36.0;47.0;34200.0;364734200.0
# 153                                               Coney Island;36.0;47.0;32800.0;364732800.0
# 154                                         Coney Island Beach;36.0;47.0;44200.0;364744200.0
# 155                                         Coney Island Beach;36.0;47.0;38200.0;364738200.0
# 156                                         Coney Island Beach;36.0;47.0;34800.0;364734800.0
# 157                                         Coney Island Beach;36.0;47.0;32600.0;364732600.0
# 158                                      Conference House Park;36.0;85.0;13203.0;368513203.0
# 159                                                Cooper Park;36.0;47.0;44902.0;364744902.0
# 160                                     Corona Golf Playground;36.0;81.0;23502.0;368123502.0
# 161                        Corporal John A. Seravalli Playground;36.0;61.0;7900.0;36617900.0
# 162                                     Corporal Thompson Park;36.0;85.0;13301.0;368513301.0
# 163                  Corporal Thompson Park/West Brighton Pool;36.0;85.0;13301.0;368513301.0
# 164                               Crocheron Park Field House;36.0;81.0;109300.0;3681109300.0
# 165                   Crotona Park (Martin Van Buren Playground);36.0;5.0;16300.0;36516300.0
# 166                       Crotona Park (Playground of the Stars);36.0;5.0;14702.0;36514702.0
# 167                                    Crotona Park (Pool House);36.0;5.0;16500.0;36516500.0
# 168                            Crotona Park Environmental Center;36.0;5.0;36902.0;36536902.0
# 169                                         Crowley Playground;36.0;81.0;49900.0;368149900.0
# 170                                          Cunningham Park;36.0;81.0;128300.0;3681128300.0
# 171                Cunningham Park (210th Street Playground);36.0;81.0;129103.0;3681129103.0
# 172                                      Cunningham Park (HQ8);36.0;81.0;47801.0;368147801.0
# 173                                       Cypress Hills Park;36.0;47.0;119600.0;3647119600.0
# 174                             Daniel M. O'Connell Playground;36.0;81.0;52200.0;368152200.0
# 175                                       De Witt Clinton Park;36.0;61.0;11700.0;366111700.0
# 176                                             Dematti Playground;36.0;85.0;800.0;3685800.0
# 177                           Detective Keith L. Williams Park;36.0;81.0;44400.0;368144400.0
# 178                                                   Devoe Park;36.0;5.0;26300.0;36526300.0
# 179                                         Digilio Playground;36.0;47.0;47800.0;364747800.0
# 180                                         Dimattina Playground;36.0;47.0;6300.0;36476300.0
# 181                                    Ditmars Park Playground;36.0;81.0;31700.0;368131700.0
# 182                                   Double Nickel Playground;36.0;85.0;15602.0;368515602.0
# 183                                    Downing Street Playground;36.0;61.0;6700.0;36616700.0
# 184                          Dr. Charles R. Drew Memorial Park;36.0;81.0;18800.0;368118800.0
# 185                          Dr. Martin Luther King Jr. Park;36.0;47.0;115800.0;3647115800.0
# 186                              Dr. Richard Greene Playground;36.0;47.0;90800.0;364790800.0
# 187                                              Drew Playground;36.0;5.0;14701.0;36514701.0
# 188                                          Dry Dock Playground;36.0;61.0;2800.0;36612800.0
# 189                                           Dugan Playground;36.0;85.0;12806.0;368512806.0
# 190                              Dutch Kills Playground (PS 112);36.0;81.0;5300.0;36815300.0
# 191                                       Dyckman House Museum;36.0;61.0;29500.0;366129500.0
# 192                                           Dyker Beach Park;36.0;47.0;19400.0;364719400.0
# 193                          East Elmhurst Playground (PS 127);36.0;81.0;35700.0;368135700.0
# 194                              East River Park (10th Street);36.0;61.0;16900.0;366116900.0
# 195                              East River Park (Tennis Courts);36.0;61.0;4500.0;36614500.0
# 196                             East River Park (Track Building);36.0;61.0;2400.0;36612400.0
# 197                                      East River Playground;36.0;61.0;16200.0;366116200.0
# 198                                East Springfield Playground;36.0;81.0;55200.0;368155200.0
# 199                                       Eastchester Playground;36.0;5.0;34800.0;36534800.0
# 200                                          Edenwald Playground;36.0;5.0;46000.0;36546000.0
# 201                                     Ederle Comfort Station;36.0;81.0;38302.0;368138302.0
# 202                                         Edmonds Playground;36.0;47.0;18300.0;364718300.0
# 203                                      Electric Playground;36.0;81.0;122703.0;3681122703.0
# 204                              Emerald Playground (PS 200);36.0;81.0;122703.0;3681122703.0
# 205                                                  Equity Park;36.0;81.0;1600.0;36811600.0
# 206                                   Ethan Allen Playground;36.0;47.0;110400.0;3647110400.0
# 207                                          Farm Playground;36.0;81.0;133300.0;3681133300.0
# 208                                           Fermi Playground;36.0;47.0;42500.0;364742500.0
# 209                                                Fisher Pool;36.0;81.0;36300.0;368136300.0
# 210           Flushing Fields (Leonardo Ingravallo Playground);36.0;81.0;77905.0;368177905.0
# 211  Flushing Meadows Corona Park (Albert H. Mauro Playground);36.0;81.0;77902.0;368177902.0
# 212         Flushing Meadows Corona Park (Lawrence Playground);36.0;81.0;80301.0;368180301.0
# 213           Flushing Meadows Corona Park (Meadow Lake North);36.0;81.0;38302.0;368138302.0
# 214                  Flushing Meadows Corona Park (Passerelle);36.0;81.0;38302.0;368138302.0
# 215 Flushing Meadows Corona Park (Playground for All Children);36.0;81.0;38302.0;368138302.0
# 216                              Hansborough Recreation Center;36.0;61.0;21200.0;366121200.0
# 217      Flushing Meadows Corona Park (Worlds Fair Playground);36.0;81.0;21200.0;368121200.0
# 218                          Flushing Meadows Corona Park (Zoo;36.0;81.0;38302.0;368138302.0
# 219                                               Flynn Playground;36.0;5.0;7100.0;3657100.0
# 220                       Forest Park (Dry Harbour Playground);36.0;81.0;63500.0;368163500.0
# 221                      Forest Park (Jackson Pond Playground);36.0;81.0;64102.0;368164102.0
# 222                           Forest Park (Seuffert Bandshell);36.0;61.0;13400.0;366113400.0
# 223                          Forest Park (Sobelsohn Playground;36.0;81.0;77500.0;368177500.0
# 224                Forest Park (Tennis Courts -Forest Parkway);36.0;81.0;64101.0;368164101.0
# 225                                 Forest Park (The Overlook);36.0;81.0;61301.0;368161301.0
# 226                              Forest Park (Victory Field);36.0;81.0;124700.0;3681124700.0
# 227                                Forest Park (Visitor Center;36.0;81.0;64102.0;368164102.0
# 228                                           Fort Greene Park;36.0;47.0;25300.0;364725300.0
# 229                                       Fort Greene Playground;36.0;47.0;2901.0;36472901.0
# 230                                 Fort Independence Playground;36.0;5.0;40900.0;36540900.0
# 231                   Fort Tryon Park (Anne Loftus Playground);36.0;61.0;29500.0;366129500.0
# 232                                     Fort Tryon Park (Café);36.0;61.0;28700.0;366128700.0
# 233                            Fort Tryon Park (The Cloisters);36.0;61.0;28700.0;366128700.0
# 234               Fort Washington Park (Lily Brown Playground);36.0;61.0;24301.0;366124301.0
# 235                                             Fox Playground;36.0;47.0;67800.0;364767800.0
# 236                                   Francis Lewis Playground;36.0;81.0;97300.0;368197300.0
# 237                               Frank D. O'Connor Playground;36.0;81.0;26700.0;368126700.0
# 238                                          Frank Golden Park;36.0;81.0;80302.0;368180302.0
# 239                                               Franz Sigel Park;36.0;5.0;6301.0;3656301.0
# 240                     Frederick B. Judge Memorial Playground;36.0;81.0;17000.0;368117000.0
# 241                              Frederick Douglass Playground;36.0;61.0;14300.0;366114300.0
# 242                             Frederick E. Samuel Playground;36.0;61.0;21703.0;366121703.0
# 243                                     Frederick Johnson Park;36.0;61.0;23600.0;366123600.0
# 244                        Fresh Meadows Playground (PS 173);36.0;81.0;122300.0;3681122300.0
# 245                                              Friends Field;36.0;47.0;44800.0;364744800.0
# 246                                                Fulton Park;36.0;47.0;29700.0;364729700.0
# 247                                          Galapo Playground;36.0;47.0;57600.0;364757600.0
# 248                                       Garibaldi Playground;36.0;47.0;27600.0;364727600.0
# 249                               General Douglas MacArthur Park;36.0;61.0;8603.0;36618603.0
# 250                                        Glenwood Playground;36.0;47.0;95000.0;364795000.0
# 251                                            Gorman Playground;36.0;81.0;1200.0;36811200.0
# 252                                        Gouverneur Playground;36.0;5.0;14701.0;36514701.0
# 253                                           Gowanus Playground;36.0;47.0;7100.0;36477100.0
# 254                                       Grandview Playground;36.0;85.0;31901.0;368531901.0
# 255                                             Gravesend Park;36.0;47.0;47000.0;364747000.0
# 256                              Greencroft Playground (PS 53);36.0;85.0;13203.0;368513203.0
# 257                                          Greene Playground;36.0;47.0;19700.0;364719700.0
# 258                                       Greenwood Playground;36.0;47.0;45000.0;364745000.0
# 259                                          Grove Hill Playground;36.0;5.0;6900.0;3656900.0
# 260                                      Grover Cleveland Park;36.0;81.0;59501.0;368159501.0
# 261                                          Gun Hill Playground;36.0;5.0;37200.0;36537200.0
# 262                                          Gunn Park (PS 18);36.0;81.0;47801.0;368147801.0
# 263                                                  Haffen Park;36.0;5.0;35800.0;36535800.0
# 264                                                  Haffen Park;36.0;5.0;35800.0;36535800.0
# 265                                              Haggerty Park;36.0;81.0;50000.0;368150000.0
# 266                                      Hallets Cove Playground;36.0;81.0;8700.0;36818700.0
# 267                       Hamilton Fish Park (Recreation Center);36.0;61.0;3002.0;36613002.0
# 268                                      Hamilton-Metz Field;36.0;47.0;107800.0;3647107800.0
# 269                                          Hammel Playground;36.0;81.0;94203.0;368194203.0
# 270                                   Happy Warrior Playground;36.0;61.0;18500.0;366118500.0
# 271                      Harold Schneiderman Playground (PS 232);36.0;81.0;6202.0;36816202.0
# 272                                                  Harris Park;36.0;5.0;40900.0;36540900.0
# 273                                   Harry Maze Memorial Park;36.0;61.0;10601.0;366110601.0
# 274                                            Hart Playground;36.0;81.0;27900.0;368127900.0
# 275                                              Harvey Park;36.0;81.0;103300.0;3681103300.0
# 276                                  Hattie Carthan Playground;36.0;47.0;25700.0;364725700.0
# 277                                           Havemeyer Playground;36.0;5.0;7000.0;3657000.0
# 278                                       Heckscher Playground;36.0;47.0;44100.0;364744100.0
# 279                                            Henry Hudson Park;36.0;5.0;29301.0;36529301.0
# 280                                      Herbert Von King Park;36.0;47.0;26300.0;364726300.0
# 281                                   Herman Dolgon Playground;36.0;47.0;57000.0;364757000.0
# 282                                        Hermon MacNeil Park;36.0;81.0;92500.0;368192500.0
# 283                                             High Rock Park;36.0;85.0;27900.0;368527900.0
# 284                        High Rock Park (Education Building);36.0;85.0;27900.0;368527900.0
# 285                             High Rock Park (McArthur Park);36.0;85.0;27900.0;368527900.0
# 286                            High Rock Park (Visitor Center);36.0;85.0;27900.0;368527900.0
# 287                     Highbridge Park (Quisqueya Playground);36.0;61.0;26100.0;366126100.0
# 288                        Highbridge Park (Recreation Center);36.0;61.0;28700.0;366128700.0
# 289                    Highbridge Park (Wallenberg Playground);36.0;61.0;27700.0;366127700.0
# 290                      Highbridge Park-Wallenberg Playground;36.0;61.0;27700.0;366127700.0
# 291                                            Highland Park;36.0;47.0;114202.0;3647114202.0
# 292                                               Hoffman Park;36.0;81.0;47500.0;368147500.0
# 293                                            Holcombe Rucker;36.0;61.0;23600.0;366123600.0
# 294                                Hollis Playground (JHS 192);36.0;81.0;51000.0;368151000.0
# 295                             Holy Cow Playground (PS 179);36.0;81.0;140902.0;3681140902.0
# 296                                          Hoover Playground;36.0;81.0;22001.0;368122001.0
# 297                         Horace Harding Playground (PS 206);36.0;81.0;69500.0;368169500.0
# 298                                         Horseshoe Playground;36.0;5.0;12901.0;36512901.0
# 299                                  Howard Bennett Playground;36.0;61.0;14300.0;366114300.0
# 300                                       Hunts Point Playground;36.0;5.0;11701.0;36511701.0
# 301                           Inwood Hill Park (Nature Center);36.0;61.0;29700.0;366129700.0
# 302                       Inwood Hill Park (Payson Playground);36.0;61.0;29700.0;366129700.0
# 303                           Inwood Hill Park (Tennis Courts);36.0;61.0;30300.0;366130300.0
# 304                                        J. Hood Wright Park;36.0;61.0;25100.0;366125100.0
# 305                                     J.J. Byrne Memorial Park;36.0;47.0;8200.0;36478200.0
# 306                                       Jackie Robinson Park;36.0;47.0;37900.0;364737900.0
# 307                                       Jackie Robinson Park;36.0;61.0;23100.0;366123100.0
# 308       Jackie Robinson Park (Playground One Fifty Two CLII);36.0;61.0;23501.0;366123501.0
# 309                   Jackie Robinson Park (Recreation Center);36.0;61.0;23501.0;366123501.0
# 310                                 Jackie Robinson Playground;36.0;47.0;32500.0;364732500.0
# 311                           Jacob Schiff Playground (PS 192);36.0;61.0;22301.0;366122301.0
# 312             James J. Walker Park (Carmine Recreation Center);36.0;61.0;6900.0;36616900.0
# 313                                     Jesse Owens Playground;36.0;47.0;28900.0;364728900.0
# 314                                         John Golden Park;36.0;81.0;115100.0;3681115100.0
# 315                                         John J. Carty Park;36.0;47.0;16200.0;364716200.0
# 316                                       John Jay Park & Pool;36.0;61.0;14200.0;366114200.0
# 317                                       John Paul Jones Park;36.0;47.0;16200.0;364716200.0
# 318                 Joline Pool Playground (Modular Equipment);36.0;85.0;24401.0;368524401.0
# 319                 Joline Pool Playground (Modular Equipment);36.0;85.0;24401.0;368524401.0
# 320                                   Joseph Austin Playground;36.0;81.0;45200.0;368145200.0
# 321                                      Joseph F. Mafera Park;36.0;81.0;58100.0;368158100.0
# 322                                           Julio Carballo Field;36.0;5.0;9800.0;3659800.0
# 323              Juniper Valley Park (North Playground Tennis);36.0;81.0;67100.0;368167100.0
# 324                          K.L. Williams Playground (Tennis);36.0;81.0;44400.0;368144400.0
# 325                                                Kaiser Park;36.0;47.0;34800.0;364734800.0
# 326                                         Katzman Playground;36.0;81.0;71100.0;368171100.0
# 327                                    Kennedy King Playground;36.0;47.0;88200.0;364788200.0
# 328                                       Kennedy Playground;36.0;81.0;109700.0;3681109700.0
# 329             Kissena Corridor East (Underhill Playground);36.0;81.0;141700.0;3681141700.0
# 330                                               Kissena Park;36.0;81.0;40302.0;368140302.0
# 331                             Kissena Park (Tennis Courts);36.0;81.0;119900.0;3681119900.0
# 332                                 La Guardia Playground West;36.0;47.0;51900.0;364751900.0
# 333                              Lawerence Virgilio Playground;36.0;81.0;25100.0;368125100.0
# 334                               Leif Ericson Park & Square;39.0;35.0;106200.0;3935106200.0
# 335                                            Levy Playground;36.0;85.0;20702.0;368520702.0
# 336                                               Liberty Pool;36.0;81.0;44000.0;368144000.0
# 337                                       Lincoln Terrace Park;36.0;47.0;35702.0;364735702.0
# 338         Lincoln Terrace Park (Arthur S. Somers Playground);36.0;47.0;34901.0;364734901.0
# 339                                              Linden Park;36.0;47.0;113200.0;3647113200.0
# 340                                                Linden Park;36.0;81.0;40501.0;368140501.0
# 341                                              Lindower Park;36.0;47.0;69800.0;364769800.0
# 342                                       Little Flower Playground;36.0;61.0;600.0;3661600.0
# 343                                  London Planetree Playground;36.0;81.0;3400.0;36813400.0
# 344                                       Loreto Park Playground;36.0;5.0;25400.0;36525400.0
# 345                                               Loring Field;36.0;81.0;84602.0;368184602.0
# 346                                        Lost Battalion Hall;36.0;81.0;60300.0;368160300.0
# 347                                      Lou Lodati Playground;36.0;81.0;18102.0;368118102.0
# 348                        Louis Armstrong Playground (PS 143);36.0;81.0;27900.0;368127900.0
# 349                                       Louis Pasteur Park;36.0;81.0;150701.0;3681150701.0
# 350                                              Lozada Playground;36.0;5.0;2300.0;3652300.0
# 351                                       Luna Park Playground;36.0;47.0;35200.0;364735200.0
# 352                                                   Lyons Pool;36.0;85.0;2100.0;36852100.0
# 353                                             Macombs Dam Park;36.0;5.0;14100.0;36514100.0
# 354                                           Magenta Playground;36.0;5.0;37400.0;36537400.0
# 355                                             Mahoney Playground;36.0;85.0;700.0;3685700.0
# 356                                                   Mapes Pool;36.0;5.0;37100.0;36537100.0
# 357                                           Maple Playground;36.0;81.0;85300.0;368185300.0
# 358                                       Marble Hill Playground;36.0;5.0;28900.0;36528900.0
# 359                                               Marconi Park;36.0;81.0;25401.0;368125401.0
# 360                                Marc's & Jason's Playground;36.0;47.0;32900.0;364732900.0
# 361        Marcus Garvey Park (Pelham Fritz Recreation Center);36.0;61.0;19800.0;366119800.0
# 362                                  Marcus Garvey Park (Pool);36.0;61.0;19600.0;366119600.0
# 363                                       Maria Hernandez Park;36.0;47.0;42900.0;364742900.0
# 364                               Marie Curie Park (JHS 158);36.0;81.0;145101.0;3681145101.0
# 365                                                Marine Park;36.0;47.0;38800.0;364738800.0
# 366                                  Marine Park Nature Center;36.0;47.0;66600.0;364766600.0
# 367                                Marion-Hopkinson Playground;36.0;47.0;37100.0;364737100.0
# 368                                         Markham Playground;36.0;85.0;13800.0;368513800.0
# 369                                  Martin Luther King Houses;36.0;61.0;18600.0;366118600.0
# 370                                        Martinez Playground;36.0;47.0;50500.0;364750500.0
# 371                                    Mathew Muliner Playground;36.0;5.0;23200.0;36523200.0
# 372                           Maurice A. Fitzgerald Playground;36.0;81.0;11600.0;368111600.0
# 373                                               Maurice Park;36.0;81.0;51100.0;368151100.0
# 374                                    May Matthews Playground;36.0;61.0;12101.0;366112101.0
# 375                                            Mazzei Playground;36.0;5.0;32600.0;36532600.0
# 376                                       McCaffrey Playground;36.0;61.0;14500.0;366114500.0
# 377                                              McCarren Park;36.0;47.0;51700.0;364751700.0
# 378                                        McDonald Playground;36.0;47.0;45000.0;364745000.0
# 379                                        McDonald Playground;36.0;61.0;12500.0;366112500.0
# 380                                              McKinley Park;36.0;47.0;13600.0;364713600.0
# 381                                          McKinley Playground;36.0;61.0;3200.0;36613200.0
# 382                                              McLaughlin Park;36.0;47.0;1300.0;36471300.0
# 383                                           Mellett Playground;36.0;61.0;5200.0;36615200.0
# 384                                          Metropolitan Pool;36.0;47.0;55300.0;364755300.0
# 385                                   Michaelis-Bayswater Park;36.0;81.0;99200.0;368199200.0
# 386                                    Midland Beach & Boardwalk;36.0;85.0;7002.0;36857002.0
# 387                                              Midland Field;36.0;85.0;11203.0;368511203.0
# 388                                         Midland Playground;36.0;85.0;11203.0;368511203.0
# 389                                           Millbrook Playground;36.0;5.0;2701.0;3652701.0
# 390                                   Monsignor Mcgolrick Park;36.0;47.0;58901.0;364758901.0
# 391                                           Montbellier Park;36.0;81.0;32800.0;368132800.0
# 392                                           Morningside Park;36.0;61.0;20901.0;366120901.0
# 393                                           Morningside Park;36.0;61.0;19701.0;366119701.0
# 394                                     Morningside Playground;36.0;61.0;19701.0;366119701.0
# 395                                    Mosholu Playground (PS 8);36.0;5.0;42500.0;36542500.0
# 396                                              Mott Playground;36.0;5.0;19700.0;36519700.0
# 397                                                Msgnr. Kett;36.0;61.0;29100.0;366129100.0
# 398                                          Mt. Prospect Park;36.0;47.0;20700.0;364720700.0
# 399                                  Mullaly Park (Skate Building);36.0;5.0;6301.0;3656301.0
# 400                                              Murray Playground;36.0;81.0;103.0;3681103.0
# 401                                        Nautilus Playground;36.0;81.0;33401.0;368133401.0
# 402                                            Nelson Playground;36.0;5.0;19900.0;36519900.0
# 403                                         Newport Playground;36.0;47.0;91800.0;364791800.0
# 404                                               Noble Playground;36.0;5.0;6000.0;3656000.0
# 405                                          Noonan Playground;36.0;81.0;18502.0;368118502.0
# 406                          North Rochdale Playground (PS 30);36.0;81.0;28400.0;368128400.0
# 407                                        Nostrand Playground;36.0;47.0;82800.0;364782800.0
# 408                                      Ocean Hill Playground;36.0;47.0;36501.0;364736501.0
# 409                                          Old Town Playground;36.0;85.0;6400.0;36856400.0
# 410                                          Oracle Playground;36.0;47.0;18501.0;364718501.0
# 411                                         Orchard Beach Pavilion;36.0;5.0;5001.0;3655001.0
# 412                                         Orchard Beach Pavilion;36.0;5.0;5001.0;3655001.0
# 413                                Orville & Wilbur Playground;36.0;61.0;23501.0;366123501.0
# 414                                          Osborn Playground;36.0;47.0;92200.0;364792200.0
# 415                                 Owen Dolen Recreation Center;36.0;5.0;21601.0;36521601.0
# 416                             P.O. Nicholas Demutis Playground;36.0;81.0;9400.0;36819400.0
# 417                                        P.O. Serrano Playground;36.0;5.0;9800.0;3659800.0
# 418                                             Paerdegat Park;36.0;47.0;83400.0;364783400.0
# 419                               Painters Playground (PS 174);36.0;81.0;69702.0;368169702.0
# 420                                      Park Slope Playground;36.0;47.0;31702.0;364731702.0
# 421                                          Parkside Playground;36.0;5.0;33602.0;36533602.0
# 422                                        Parkside Playground;36.0;47.0;79802.0;364779802.0
# 423                                     Pat Perlato Playground;36.0;47.0;62000.0;364762000.0
# 424         Paul W. Kolbert Park/Rachel Haber Cohen Playground;36.0;47.0;53800.0;364753800.0
# 425      Pelham Bay Park (Bruckner Boulevard and Wilkinson Avenue);36.0;5.0;5001.0;3655001.0
# 426                                  Pelham Bay Park (Bruckner CS);36.0;5.0;5001.0;3655001.0
# 427                    Pelham Bay Park (Hunter Island Picnic Area);36.0;5.0;5001.0;3655001.0
# 428                Pelham Bay Park (Playground for All Children);36.0;5.0;27600.0;36527600.0
# 429                                 Pelham South Park Headquarters;36.0;5.0;5001.0;3655001.0
# 430                                       People's Park Playground;36.0;5.0;3900.0;3653900.0
# 431                                              Peter's Field;36.0;81.0;40400.0;368140400.0
# 432                      PFC Thomas Norton Memorial Playground;36.0;47.0;64400.0;364764400.0
# 433                                          Pierrepont Playground;36.0;47.0;301.0;3647301.0
# 434                                          Pink Playground;36.0;47.0;122000.0;3647122000.0
# 435                                     Playground 62 (PS 220);36.0;81.0;60300.0;368160300.0
# 436                                              Playground 70;36.0;61.0;15900.0;366115900.0
# 437                            Playground 90/PS 148 Playground;36.0;81.0;33900.0;368133900.0
# 438                                           Playground Fifty-Two;36.0;5.0;8500.0;3658500.0
# 439                               Playground Ninety Six (XCVI);36.0;61.0;15802.0;366115802.0
# 440                         Playground Seventy-Five (PS 154);36.0;81.0;125700.0;3681125700.0
# 441                 Police Officer Reinaldo Salgado Playground;36.0;47.0;38500.0;364738500.0
# 442                                  Poor Richard's Playground;36.0;61.0;17200.0;366117200.0
# 443                                         Potomac Playground;36.0;47.0;26700.0;364726700.0
# 444                                           Pratt Playground;36.0;47.0;19300.0;364719300.0
# 445                                        Prescott Playground;36.0;85.0;19800.0;368519800.0
# 446                        Prospect Park (East Parade Grounds);36.0;47.0;52600.0;364752600.0
# 447                           Prospect Park (Litchfield Villa);36.0;47.0;16500.0;364716500.0
# 448                         Prospect Park (Middle Long Meadow);36.0;47.0;17700.0;364717700.0
# 449                              Prospect Park (The Bandshell);36.0;47.0;14101.0;364714101.0
# 450                        Prospect Park (West Parade Grounds);36.0;47.0;44200.0;364744200.0
# 451                               Prospect Park (Willink Hill);36.0;47.0;32700.0;364732700.0
# 452                               Prospect Park (Willink Hill);36.0;47.0;32700.0;364732700.0
# 453               Prospect Park (Wollman Rink & Flower Garden);36.0;47.0;17700.0;364717700.0
# 454                                              PS 1 Playground;36.0;47.0;1803.0;36471803.0
# 455                                          PS 155 Playground;36.0;61.0;11800.0;366111800.0
# 456                                          PS 286 Playground;36.0;47.0;57200.0;364757200.0
# 457                                    PS 59 Sumner Playground;36.0;81.0;55300.0;368155300.0
# 458                                            Quarry Ballfields;36.0;5.0;37504.0;36537504.0
# 459                                       Queens Farm Museum;36.0;81.0;157101.0;3681157101.0
# 460                                        Queensbridge Park;36.0;81.0;124700.0;3681124700.0
# 461                                        Railroad Playground;36.0;47.0;31300.0;364731300.0
# 462                                                  Rainey Park;36.0;5.0;12701.0;36512701.0
# 463                                                  Rainey Park;36.0;81.0;3900.0;36813900.0
# 464                                             Randall Playground;36.0;5.0;9000.0;3659000.0
# 465                                         Rappaport Playground;36.0;47.0;1803.0;36471803.0
# 466                            Real Good Park (Lie Playground);36.0;81.0;71900.0;368171900.0
# 467                                                Red Hook Park;36.0;47.0;5302.0;36475302.0
# 468                                                Red Hook Park;36.0;47.0;4500.0;36474500.0
# 469                       Red Hook Park (Coffey Park Playground);36.0;47.0;8500.0;36478500.0
# 470                            Red Hook Park (Recreation Center);36.0;47.0;5302.0;36475302.0
# 471                                           Reiff Playground;36.0;81.0;59900.0;368159900.0
# 472                                     Renaissance Playground;36.0;61.0;22700.0;366122700.0
# 473                                       Rev. Polite Playground;36.0;5.0;13100.0;36513100.0
# 474                               Richman (Echo) Park Playground;36.0;5.0;38100.0;36538100.0
# 475                                            Rienzi Playground;36.0;5.0;40600.0;36540600.0
# 476                                         Riverbend Playground;36.0;5.0;27300.0;36527300.0
# 477                                Riverside Park (Boat Basin);36.0;61.0;21900.0;366121900.0
# 478                                      Riverside Park (Café);36.0;61.0;22900.0;366122900.0
# 479                                 Riverside Park (Claremont);36.0;61.0;20000.0;366120000.0
# 480                        Riverside Park (Classic Playground);36.0;61.0;22900.0;366122900.0
# 481                       Riverside Park (Dinosaur Playground);36.0;61.0;18300.0;366118300.0
# 482                          Riverside Park (Hippo Playground);36.0;61.0;17900.0;366117900.0
# 483                        Riverside Park (Neufeld Playground);36.0;61.0;16300.0;366116300.0
# 484                      Riverside Park (River Run Playground);36.0;61.0;17100.0;366117100.0
# 485                      Riverside Park (Riverbank Playground);36.0;61.0;22900.0;366122900.0
# 486                 Riverside Park (Ten Mile River Playground);36.0;61.0;23100.0;366123100.0
# 487                             Riverside Park (Tennis Courts);36.0;61.0;20500.0;366120500.0
# 488                                      Robert Moses Playground;36.0;61.0;8000.0;36618000.0
# 489                                              Rochdale Park;36.0;81.0;29400.0;368129400.0
# 490                                             Rockaway Beach;36.0;81.0;88400.0;368188400.0
# 491                                             Rockaway Beach;36.0;81.0;74500.0;368174500.0
# 492  Rockaway Beach & Boardwalk (Beach 59th Street Playground);36.0;81.0;52500.0;368152500.0
# 493                               Rockaway Beach (Beach 116Th);36.0;81.0;16600.0;368116600.0
# 494                         Rockaway Beach 106 Comfort Station;36.0;81.0;93800.0;368193800.0
# 495                                   Rockaway Beach 117th L/G;36.0;81.0;93402.0;368193402.0
# 496                          Rockaway Beach 86 Comfort Station;36.0;81.0;94202.0;368194202.0
# 497                          Rockaway Beach 97 Comfort Station;36.0;81.0;94201.0;368194201.0
# 498                                    Rodney Playground South;36.0;47.0;54900.0;364754900.0
# 499                                        Roebling Playground;36.0;47.0;53500.0;364753500.0
# 500                   Roger Morris Park (Morris Jumel Mansion);36.0;61.0;24301.0;366124301.0
# 501                                      Rolf Henry Playground;36.0;47.0;80800.0;364780800.0
# 502                                               Rose Hill Park;36.0;5.0;39700.0;36539700.0
# 503                             Rosemary's Playground (JHS 93);36.0;81.0;58900.0;368158900.0
# 504                            Roy Wilkins Recreation Center;36.0;81.0;124700.0;3681124700.0
# 505                            Roy Wilkins Recreation Center;36.0;81.0;124700.0;3681124700.0
# 506                                            Rudd Playground;36.0;47.0;40500.0;364740500.0
# 507                                            Rufus King Park;36.0;81.0;24000.0;368124000.0
# 508                                Russell Pederson Playground;36.0;47.0;15000.0;364715000.0
# 509                          Russell Sage Playground (JHS 190);36.0;81.0;71100.0;368171100.0
# 510                                       Sara D. Roosevelt Park;36.0;61.0;3300.0;36613300.0
# 511                                       Saratoga Square Park;36.0;47.0;37700.0;364737700.0
# 512                                                Schmul Park;36.0;85.0;29102.0;368529102.0
# 513                                Seaside Playground (PS 225);36.0;81.0;93800.0;368193800.0
# 514                                        Seth Low Playground;36.0;47.0;26600.0;364726600.0
# 515                                                   Seton Park;36.0;5.0;30100.0;36530100.0
# ...
# 828                                                                         ;nan;nan;nan;nan
# 829                                                                         ;nan;nan;nan;nan
# 830                                                                         ;nan;nan;nan;nan
# 831                                                                         ;nan;nan;nan;nan
# 832                                                                         ;nan;nan;nan;nan
# 833                                                                         ;nan;nan;nan;nan
# 834                                                                         ;nan;nan;nan;nan
# 835                                                                         ;nan;nan;nan;nan
# 836                                                                         ;nan;nan;nan;nan
# 837                                                                         ;nan;nan;nan;nan
# 838                                                                         ;nan;nan;nan;nan
# 839                                                                         ;nan;nan;nan;nan
# 840                                                                         ;nan;nan;nan;nan
# 841                                                                         ;nan;nan;nan;nan
# 842                                                                         ;nan;nan;nan;nan
# 843                                                                         ;nan;nan;nan;nan
# 844                                                                         ;nan;nan;nan;nan
# 845                                                                         ;nan;nan;nan;nan
# 846                                                                         ;nan;nan;nan;nan
# 847                                                                         ;nan;nan;nan;nan
# 848                                                                         ;nan;nan;nan;nan
# 849                                                                         ;nan;nan;nan;nan
# 850                                                                         ;nan;nan;nan;nan
# 851                                                                         ;nan;nan;nan;nan
# 852                                                                         ;nan;nan;nan;nan
# 853                                                                         ;nan;nan;nan;nan
# 854                                                                         ;nan;nan;nan;nan
# 855                                                                         ;nan;nan;nan;nan
# 856                                                                         ;nan;nan;nan;nan
# 857                                                                         ;nan;nan;nan;nan
# 858                                                                         ;nan;nan;nan;nan
# 859                                                                         ;nan;nan;nan;nan
# 860                                                                         ;nan;nan;nan;nan
# 861                                                                         ;nan;nan;nan;nan
# 862                                                                         ;nan;nan;nan;nan
# 863                                                                         ;nan;nan;nan;nan
# 864                                                                         ;nan;nan;nan;nan
# 865                                                                         ;nan;nan;nan;nan
# 866                                                                         ;nan;nan;nan;nan
# 867                                                                         ;nan;nan;nan;nan
# 868                                                                         ;nan;nan;nan;nan
# 869                                                                         ;nan;nan;nan;nan
# 870                                                                         ;nan;nan;nan;nan
# 871                                                                         ;nan;nan;nan;nan
# 872                                                                         ;nan;nan;nan;nan
# 873                                                                         ;nan;nan;nan;nan
# 874                                                                         ;nan;nan;nan;nan
# 875                                                                         ;nan;nan;nan;nan
# 876                                                                         ;nan;nan;nan;nan
# 877                                                                         ;nan;nan;nan;nan
# 878                                                                         ;nan;nan;nan;nan
# 879                                                                         ;nan;nan;nan;nan
# 880                                                                         ;nan;nan;nan;nan
# 881                                                                         ;nan;nan;nan;nan
# 882                                                                         ;nan;nan;nan;nan
# 883                                                                         ;nan;nan;nan;nan
# 884                                                                         ;nan;nan;nan;nan
# 885                                                                         ;nan;nan;nan;nan
# 886                                                                         ;nan;nan;nan;nan
# 887                                                                         ;nan;nan;nan;nan
# 888                                                                         ;nan;nan;nan;nan
# 889                                                                         ;nan;nan;nan;nan
# 890                                                                         ;nan;nan;nan;nan
# 891                                                                         ;nan;nan;nan;nan
# 892                                                                         ;nan;nan;nan;nan
# 893                                                                         ;nan;nan;nan;nan
# 894                                                                         ;nan;nan;nan;nan
# 895                                                                         ;nan;nan;nan;nan
# 896                                                                         ;nan;nan;nan;nan
# 897                                                                         ;nan;nan;nan;nan
# 898                                                                         ;nan;nan;nan;nan
# 899                                                                         ;nan;nan;nan;nan
# 900                                                                         ;nan;nan;nan;nan
# 901                                                                         ;nan;nan;nan;nan
# 902                                                                         ;nan;nan;nan;nan
# 903                                                                         ;nan;nan;nan;nan
# 904                                                                         ;nan;nan;nan;nan
# 905                                                                         ;nan;nan;nan;nan
# 906                                                                         ;nan;nan;nan;nan
# 907                                                                         ;nan;nan;nan;nan
# 908                                                                         ;nan;nan;nan;nan
# 909                                                                         ;nan;nan;nan;nan
# 910                                                                         ;nan;nan;nan;nan
# 911                                                                         ;nan;nan;nan;nan
# 912                                                                         ;nan;nan;nan;nan
# 913                                                                         ;nan;nan;nan;nan
# 914                                                                         ;nan;nan;nan;nan
# 915                                                                         ;nan;nan;nan;nan
# 916                                                                         ;nan;nan;nan;nan
# 917                                                                         ;nan;nan;nan;nan
# 918                                                                         ;nan;nan;nan;nan
# 919                                                                         ;nan;nan;nan;nan
# 920                                                                         ;nan;nan;nan;nan
# 921                                                                         ;nan;nan;nan;nan
# 922                                                                         ;nan;nan;nan;nan
# 923                                                                         ;nan;nan;nan;nan
# 924                                                                         ;nan;nan;nan;nan
# 925                                                                         ;nan;nan;nan;nan
# 926                                                                         ;nan;nan;nan;nan
# 927                                                                         ;nan;nan;nan;nan
# 928                                                                         ;nan;nan;nan;nan
# 929                                                                         ;nan;nan;nan;nan
# 930                                                                         ;nan;nan;nan;nan
# 931                                                                         ;nan;nan;nan;nan
# 932                                                                         ;nan;nan;nan;nan
# 933                                                                         ;nan;nan;nan;nan
# 934                                                                         ;nan;nan;nan;nan
# 935                                                                         ;nan;nan;nan;nan
# 936                                                                         ;nan;nan;nan;nan
# 937                                                                         ;nan;nan;nan;nan
# 938                                                                         ;nan;nan;nan;nan
# 939                                                                         ;nan;nan;nan;nan
# 940                                                                         ;nan;nan;nan;nan
# 941                                                                         ;nan;nan;nan;nan
# 942                                                                         ;nan;nan;nan;nan
# 943                                                                         ;nan;nan;nan;nan
# 944                                                                         ;nan;nan;nan;nan
# 945                                                                         ;nan;nan;nan;nan
# 946                                                                         ;nan;nan;nan;nan
# 947                                                                         ;nan;nan;nan;nan
# 948                                                                         ;nan;nan;nan;nan
# 949                                                                         ;nan;nan;nan;nan
# 950                                                                         ;nan;nan;nan;nan
# 951                                                                         ;nan;nan;nan;nan
# 952                                                                         ;nan;nan;nan;nan
# 953                                                                         ;nan;nan;nan;nan
# 954                                                                         ;nan;nan;nan;nan
# 955                                                                         ;nan;nan;nan;nan
# 956                                                                         ;nan;nan;nan;nan
# 957                                                                         ;nan;nan;nan;nan
# 958                                                                         ;nan;nan;nan;nan
# 959                                                                         ;nan;nan;nan;nan
# 960                                                                         ;nan;nan;nan;nan
# 961                                                                         ;nan;nan;nan;nan
# 962                                                                         ;nan;nan;nan;nan
# 963                                                                         ;nan;nan;nan;nan
# 964                                                                         ;nan;nan;nan;nan
# 965                                                                         ;nan;nan;nan;nan
# 966                                                                         ;nan;nan;nan;nan
# 967                                                                         ;nan;nan;nan;nan
# 968                                                                         ;nan;nan;nan;nan
# 969                                                                         ;nan;nan;nan;nan
# 970                                                                         ;nan;nan;nan;nan
# 971                                                                         ;nan;nan;nan;nan
# 972                                                                         ;nan;nan;nan;nan
# 973                                                                         ;nan;nan;nan;nan
# 974                                                                         ;nan;nan;nan;nan
# 975                                                                         ;nan;nan;nan;nan
# 976                                                                         ;nan;nan;nan;nan
# 977                                                                         ;nan;nan;nan;nan
# 978                                                                         ;nan;nan;nan;nan
# 979                                                                         ;nan;nan;nan;nan
# 980                                                                         ;nan;nan;nan;nan
# 981                                                                         ;nan;nan;nan;nan
# 982                                                                         ;nan;nan;nan;nan
# 983                                                                         ;nan;nan;nan;nan
# 984                                                                         ;nan;nan;nan;nan
# 985                                                                         ;nan;nan;nan;nan
# 986                                                                         ;nan;nan;nan;nan
# 987                                                                         ;nan;nan;nan;nan
# 988                                                                         ;nan;nan;nan;nan
# 989                                                                         ;nan;nan;nan;nan
# 990                                                                         ;nan;nan;nan;nan
# 991                                                                         ;nan;nan;nan;nan
# 992                                                                         ;nan;nan;nan;nan
# 993                                                                         ;nan;nan;nan;nan
# 994                                                                         ;nan;nan;nan;nan
# 995                                                                         ;nan;nan;nan;nan
# 996                                                                         ;nan;nan;nan;nan
# 997                                                                         ;nan;nan;nan;nan
# 998                                                                         ;nan;nan;nan;nan
# 999                                                                         ;nan;nan;nan;nan

# %%
# %%R
# # Check column names
# colnames(df)
# Out:
# UsageError: Cell magic `%%R` not found.

# %% [markdown]
# ## 👉 Grab Census Data

# %% [markdown]
# 1. loading the Census API key

# %%
import dotenv

# Load the environment variables
# (loads CENSUS_API_KEY from .env)
dotenv.load_dotenv()

CENSUS_API_KEY = "a435d72f84653a5895173d187536a34d55ac0afc"

# %%
# %%R
#
# require('tidycensus')
#
# # because it an environment variable, we don't have to
# # explicitly pass this string to R, it is readable here
# # in this R cell.
# census_api_key(Sys.getenv("a435d72f84653a5895173d187536a34d55ac0afc"))
# Out:
# To install your API key for use in future sessions, run this function with `install = TRUE`.

# %% [markdown]
# 2. Decide which Census variables you want
#
#     Use <https://censusreporter.org/> to figure out which tables you want. (if censusreporter is down, check out the code in the cell below)
#
#     -   Scroll to the bottom of the page to see the tables.
#     -   If you already know the table ID, stick that in the "Explore" section to learn more about that table.
#
#     By default this code loads (B01003_001) which we found in censusreporter here: https://censusreporter.org/tables/B01003/
#
#     - find some other variables that you're also interested in
#     - don't forget to pick a geography like "tract", "county" or "block group". here is the list of [all geographies](https://walker-data.com/tidycensus/articles/basic-usage.html#geography-in-tidycensus
#     ).

# %%
# %%R
#
# # Finding the Census Varaibles for the ACS 5 year survey
# # Generall you'd do this in CensusReporter, but since it's down sometimes, here it is using tidycensus's load_variables function
#
# # get every single variable in the ACS5
# all_census_vars <- load_variables(2021, "acs5", cache = TRUE)
#
# filtered_census_vars <- all_census_vars %>%
#     filter(grepl("median income", label, ignore.case = TRUE))   # filter to those containing "median income"
#
# # write to CSV so we can view it in python
# filtered_census_vars %>%
#     write_csv("filtered_census_vars.csv")
#
# # show the first few rows
# filtered_census_vars %>%
#     select(-geography) %>% # remove the geography column
#     print(n = 20) # print the first 20 rows
# Out:
# # A tibble: 46 × 3
#    name         label                                                    concept
#    <chr>        <chr>                                                    <chr>
#  1 B06011PR_001 Estimate!!Median income in the past 12 months --!!Total: MEDIAN…
#  2 B06011PR_002 Estimate!!Median income in the past 12 months --!!Total… MEDIAN…
#  3 B06011PR_003 Estimate!!Median income in the past 12 months --!!Total… MEDIAN…
#  4 B06011PR_004 Estimate!!Median income in the past 12 months --!!Total… MEDIAN…
#  5 B06011PR_005 Estimate!!Median income in the past 12 months --!!Total… MEDIAN…
#  6 B06011_001   Estimate!!Median income in the past 12 months --!!Total: MEDIAN…
#  7 B06011_002   Estimate!!Median income in the past 12 months --!!Total… MEDIAN…
#  8 B06011_003   Estimate!!Median income in the past 12 months --!!Total… MEDIAN…
#  9 B06011_004   Estimate!!Median income in the past 12 months --!!Total… MEDIAN…
# 10 B06011_005   Estimate!!Median income in the past 12 months --!!Total… MEDIAN…
# 11 B07011PR_001 Estimate!!Median income in the past 12 months --!!Total: MEDIAN…
# 12 B07011PR_002 Estimate!!Median income in the past 12 months --!!Total… MEDIAN…
# 13 B07011PR_003 Estimate!!Median income in the past 12 months --!!Total… MEDIAN…
# 14 B07011PR_004 Estimate!!Median income in the past 12 months --!!Total… MEDIAN…
# 15 B07011PR_005 Estimate!!Median income in the past 12 months --!!Total… MEDIAN…
# 16 B07011PR_006 Estimate!!Median income in the past 12 months --!!Total… MEDIAN…
# 17 B07011_001   Estimate!!Median income in the past 12 months --!!Total: MEDIAN…
# 18 B07011_002   Estimate!!Median income in the past 12 months --!!Total… MEDIAN…
# 19 B07011_003   Estimate!!Median income in the past 12 months --!!Total… MEDIAN…
# 20 B07011_004   Estimate!!Median income in the past 12 months --!!Total… MEDIAN…
# # ℹ 26 more rows
# # ℹ Use `print(n = ...)` to see more rows

# %%
# %%R -o nyc_census_data
# # the variable B01003_001E was selectd from the census table
# # for population, which we found in censusreporter here:
# # https://censusreporter.org/tables/B01003/
#
# # in the table below, pick the geography, the variables, and the survey you want to pull from
# # see the possible values here https://walker-data.com/tidycensus/articles/basic-usage.html
#
# # Get variable from ACS
# nyc_census_data <- get_acs(geography = "tract",
#                       state='NY',
#                       county = c("New York", "Kings", "Queens", "Bronx", "Richmond"),
#                       variables = c(
#                         population="B01003_001",
#                         med_inc="B19013_001",
#                         poverty="B17001_001"
#                       ),
#                       year = 2021,
#                       survey="acs5",
#                       geometry=F)
#
# nyc_census_data
# Out:
# # A tibble: 6,981 × 5
#    GEOID       NAME                                    variable   estimate   moe
#    <chr>       <chr>                                   <chr>         <dbl> <dbl>
#  1 36005000100 Census Tract 1, Bronx County, New York  population     6661   702
#  2 36005000100 Census Tract 1, Bronx County, New York  poverty           0    18
#  3 36005000100 Census Tract 1, Bronx County, New York  med_inc          NA    NA
#  4 36005000200 Census Tract 2, Bronx County, New York  population     4453   563
#  5 36005000200 Census Tract 2, Bronx County, New York  poverty        4453   563
#  6 36005000200 Census Tract 2, Bronx County, New York  med_inc       70867 25423
#  7 36005000400 Census Tract 4, Bronx County, New York  population     6000   903
#  8 36005000400 Census Tract 4, Bronx County, New York  poverty        6000   903
#  9 36005000400 Census Tract 4, Bronx County, New York  med_inc       98090 18180
# 10 36005001600 Census Tract 16, Bronx County, New York population     6038   665
# # ℹ 6,971 more rows
# # ℹ Use `print(n = ...)` to see more rows
# Getting data from the 2017-2021 5-year ACS
# Using FIPS code '36' for state 'NY'
# Using FIPS code '061' for 'New York County'
# Using FIPS code '047' for 'Kings County'
# Using FIPS code '081' for 'Queens County'
# Using FIPS code '005' for 'Bronx County'
# Using FIPS code '085' for 'Richmond County'

# %%
nyc_census_data
# Out:
#             GEOID                                          NAME    variable  \
# 1     36005000100        Census Tract 1, Bronx County, New York  population
# 2     36005000100        Census Tract 1, Bronx County, New York     poverty
# 3     36005000100        Census Tract 1, Bronx County, New York     med_inc
# 4     36005000200        Census Tract 2, Bronx County, New York  population
# 5     36005000200        Census Tract 2, Bronx County, New York     poverty
# ...           ...                                           ...         ...
# 6977  36085032300   Census Tract 323, Richmond County, New York     poverty
# 6978  36085032300   Census Tract 323, Richmond County, New York     med_inc
# 6979  36085990100  Census Tract 9901, Richmond County, New York  population
# 6980  36085990100  Census Tract 9901, Richmond County, New York     poverty
# 6981  36085990100  Census Tract 9901, Richmond County, New York     med_inc
#
#       estimate      moe
# 1       6661.0    702.0
# 2          0.0     18.0
# 3          NaN      NaN
# 4       4453.0    563.0
# 5       4453.0    563.0
# ...        ...      ...
# 6977    1105.0    304.0
# 6978   86471.0  25095.0
# 6979       0.0     13.0
# 6980       0.0     13.0
# 6981       NaN      NaN
#
# [6981 rows x 5 columns]

# %%
Toilet_df = pd.read_excel('ToiletWithGeos.xlsx', dtype={'GEOID': str}) 
Toilet_df['GEOID'] = Toilet_df['GEOID'].astype(str).str[:11]

Toilet_df
# Out:
#                         Name  \
# 0            100% Playground
# 1    174th Street Playground
# 2      227 Street Playground
# 3                Abe Lincoln
# 4         Abigail Playground
# ..                       ...
# 611             Wingate Park
# 612         Woods Playground
# 613      Woodtree Playground
# 614           Yak Playground
# 615     Zimmerman Playground
#
#                                               Location Open Year-Round  \
# 0           Glenwood Road, East 100 & East 101 streets             Yes
# 1    East 174 Street, Stratford Avenue, Bronx River...             Yes
# 2    Bronx Boulevard between East 226 and East 228 ...             Yes
# 3         East 135 Street, between Madison & 5 avenues             Yes
# 4                       East 156 Street, Tinton Avenue              No
# ..                                                 ...             ...
# 611                     Brooklyn Avenue & Rutland Road             Yes
# 612                       Bergen Street & Utica Avenue             Yes
# 613                    20 Avenue, 37 Street, 38 Street             Yes
# 614        Avenue Y between Coyle & Batchelder streets             Yes
# 615    Britton Street, Barker Avenue, Olinville Avenue              No
#
#     Handicap Accessible    Borough Comments   Latitude  Longitude  \
# 0                   NaN   Brooklyn      NaN  40.646908 -73.899467
# 1                   NaN      Bronx      NaN  40.833885 -73.876596
# 2                   Yes      Bronx      NaN  40.888553 -73.855013
# 3                   NaN  Manhattan      NaN  40.783060 -73.971249
# 4                   NaN      Bronx      NaN  40.817880 -73.905006
# ..                  ...        ...      ...        ...        ...
# 611                 NaN   Brooklyn      NaN  40.659723 -73.945358
# 612                 NaN   Brooklyn      NaN  40.675045 -73.930540
# 613                 NaN     Queens      NaN  40.761101 -73.919665
# 614                 Yes   Brooklyn      NaN  40.595089 -73.937972
# 615                 NaN      Bronx      NaN  40.866610 -73.869158
#
#            GEOID  STATE  COUNTY  TRACT  BLOCK
# 0    36047097400     36      47  97400   2002
# 1    36005006200     36       5   6200   3000
# 2    36005040600     36       5  40600   1001
# 3    36061016900     36      61  16900   6000
# 4    36005007900     36       5   7900   1001
# ..           ...    ...     ...    ...    ...
# 611  36047081000     36      47  81000   1004
# 612  36047030900     36      47  30900   2000
# 613  36081006100     36      81   6100   4001
# 614  36047057200     36      47  57200   2001
# 615  36005033601     36       5  33601   2001
#
# [616 rows x 13 columns]

# %%
nyc_census_data[nyc_census_data['GEOID'] == '36047097400']
# Out:
#             GEOID                                      NAME    variable  \
# 3232  36047097400  Census Tract 974, Kings County, New York  population
# 3233  36047097400  Census Tract 974, Kings County, New York     poverty
# 3234  36047097400  Census Tract 974, Kings County, New York     med_inc
#
#       estimate      moe
# 3232    2792.0    536.0
# 3233    2464.0    417.0
# 3234   76767.0  17732.0

# %%
merge = Toilet_df.merge(nyc_census_data, left_on='GEOID', right_on='GEOID')
merge

merge.to_excel('merged.xlsx', index=False)

# %%
# %%R
# #show me TRACT in the data
# Out:
# Error in `select()`:
# ! Can't subset columns that don't exist.
# ✖ Column `tract` doesn't exist.
# Run `rlang::last_trace()` to see where the error occurred.
# Error in select(., tract) :
# ---------------------------------------------------------------------------
# RRuntimeError                             Traceback (most recent call last)
# File ~/.pyenv/versions/3.11.6/lib/python3.11/site-packages/rpy2/ipython/rmagic.py:407, in RMagics.eval(self, code)
#     406     r_expr = ri.parse(code)
# --> 407     value, visible = ri.evalr_expr_with_visible(
#     408         r_expr
#     409     )
#     410 except (ri.embedded.RRuntimeError, ValueError) as exception:
#     411     # Otherwise next return seems to have copy of error.
#
# File ~/.pyenv/versions/3.11.6/lib/python3.11/site-packages/rpy2/rinterface.py:196, in evalr_expr_with_visible(expr, envir)
#     195 if error_occured[0]:
# --> 196     raise embedded.RRuntimeError(_rinterface._geterrmessage())
#     197 res = conversion._cdata_to_rinterface(r_res)
#
# RRuntimeError: Error in select(., tract) :
#
#
# During handling of the above exception, another exception occurred:
#
# RInterpreterError                         Traceback (most recent call last)
# /Users/carlamandiola/Desktop/connect-to-census/merge-with-census.ipynb Cell 16 line 1
# ----> <a href='vscode-notebook-cell:/Users/carlamandiola/Desktop/connect-to-census/merge-with-census.ipynb#X43sZmlsZQ%3D%3D?line=0'>1</a> get_ipython().run_cell_magic('R', '', '#show me TRACT in the data\nnyc_census_data %>%\n    select(tract) %>%\n    print(n=5)\n')
#
# File ~/.pyenv/versions/3.11.6/lib/python3.11/site-packages/IPython/core/interactiveshell.py:2517, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2515 with self.builtin_trap:
#    2516     args = (magic_arg_s, cell)
# -> 2517     result = fn(*args, **kwargs)
#    2519 # The code below prevents the output from being displayed
#    2520 # when using magics with decorator @output_can_be_silenced
#    2521 # when the last Python token in the expression is a ';'.
#    2522 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File ~/.pyenv/versions/3.11.6/lib/python3.11/site-packages/rpy2/ipython/rmagic.py:984, in RMagics.R(self, line, cell, local_ns)
#     982     if not e.stdout.endswith(e.err):
#     983         print(e.err)
# --> 984     raise e
#     985 finally:
#     986     if self.device in DEVICES_STATIC:
#
# File ~/.pyenv/versions/3.11.6/lib/python3.11/site-packages/rpy2/ipython/rmagic.py:949, in RMagics.R(self, line, cell, local_ns)
#     947         return_output = False
#     948 else:
# --> 949     text_result, result, visible = self.eval(code)
#     950     text_output += text_result
#     951     if visible:
#
# File ~/.pyenv/versions/3.11.6/lib/python3.11/site-packages/rpy2/ipython/rmagic.py:413, in RMagics.eval(self, code)
#     410 except (ri.embedded.RRuntimeError, ValueError) as exception:
#     411     # Otherwise next return seems to have copy of error.
#     412     warning_or_other_msg = self.flush()
# --> 413     raise RInterpreterError(code, str(exception),
#     414                             warning_or_other_msg)
#     415 finally:
#     416     ro._print_deferred_warnings()
#
# RInterpreterError: Failed to parse and evaluate line '#show me TRACT in the data\nnyc_census_data %>%\n    select(tract) %>%\n    print(n=5)\n'.
# R error message: 'Error in select(., tract) :'

# %%
# %%R
# #turn nyc_census_data as a csv file
# write.csv(nyc_census_data, "nyc_census_data2.csv")

# %%
# %%R
# nyc_census_data
# Out:
# Error in library(tmap) : there is no package called ‘tmap’
# ---------------------------------------------------------------------------
# RRuntimeError                             Traceback (most recent call last)
# File ~/.pyenv/versions/3.11.6/lib/python3.11/site-packages/rpy2/ipython/rmagic.py:407, in RMagics.eval(self, code)
#     406     r_expr = ri.parse(code)
# --> 407     value, visible = ri.evalr_expr_with_visible(
#     408         r_expr
#     409     )
#     410 except (ri.embedded.RRuntimeError, ValueError) as exception:
#     411     # Otherwise next return seems to have copy of error.
#
# File ~/.pyenv/versions/3.11.6/lib/python3.11/site-packages/rpy2/rinterface.py:196, in evalr_expr_with_visible(expr, envir)
#     195 if error_occured[0]:
# --> 196     raise embedded.RRuntimeError(_rinterface._geterrmessage())
#     197 res = conversion._cdata_to_rinterface(r_res)
#
# RRuntimeError: Error in library(tmap) : there is no package called ‘tmap’
#
#
# During handling of the above exception, another exception occurred:
#
# RInterpreterError                         Traceback (most recent call last)
# /Users/carlamandiola/Desktop/connect-to-census/merge-with-census.ipynb Cell 19 line 1
# ----> <a href='vscode-notebook-cell:/Users/carlamandiola/Desktop/connect-to-census/merge-with-census.ipynb#X21sZmlsZQ%3D%3D?line=0'>1</a> get_ipython().run_cell_magic('R', '', 'nyc_census_data\n#make a map of the data\nlibrary(tmap)\n')
#
# File ~/.pyenv/versions/3.11.6/lib/python3.11/site-packages/IPython/core/interactiveshell.py:2517, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2515 with self.builtin_trap:
#    2516     args = (magic_arg_s, cell)
# -> 2517     result = fn(*args, **kwargs)
#    2519 # The code below prevents the output from being displayed
#    2520 # when using magics with decorator @output_can_be_silenced
#    2521 # when the last Python token in the expression is a ';'.
#    2522 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File ~/.pyenv/versions/3.11.6/lib/python3.11/site-packages/rpy2/ipython/rmagic.py:984, in RMagics.R(self, line, cell, local_ns)
#     982     if not e.stdout.endswith(e.err):
#     983         print(e.err)
# --> 984     raise e
#     985 finally:
#     986     if self.device in DEVICES_STATIC:
#
# File ~/.pyenv/versions/3.11.6/lib/python3.11/site-packages/rpy2/ipython/rmagic.py:949, in RMagics.R(self, line, cell, local_ns)
#     947         return_output = False
#     948 else:
# --> 949     text_result, result, visible = self.eval(code)
#     950     text_output += text_result
#     951     if visible:
#
# File ~/.pyenv/versions/3.11.6/lib/python3.11/site-packages/rpy2/ipython/rmagic.py:413, in RMagics.eval(self, code)
#     410 except (ri.embedded.RRuntimeError, ValueError) as exception:
#     411     # Otherwise next return seems to have copy of error.
#     412     warning_or_other_msg = self.flush()
# --> 413     raise RInterpreterError(code, str(exception),
#     414                             warning_or_other_msg)
#     415 finally:
#     416     ro._print_deferred_warnings()
#
# RInterpreterError: Failed to parse and evaluate line 'nyc_census_data\n#make a map of the data\nlibrary(tmap)\n'.
# R error message: 'Error in library(tmap) : there is no package called ‘tmap’'

# %% [markdown]
# ## 👉 Merge it with your data
#
# hint...`tidycensus` provides you data in long format you may need to pivot the census data from long to wide format before merging it with your data

# %%
# %%R
# #df <- left_join(df, nyc_census_data, by==c("GEOID"=="geoid"))
#
# #pivot the census data from long to wide format
# nyc_census_data_wide <- nyc_census_data %>%
#   pivot_wider(names_from = "GEOID", values_from = "GEOID")
#
# nyc_census_data_wide
# Out:
# Simple feature collection with 6981 features and 2331 fields (with 3 geometries empty)
# Geometry type: MULTIPOLYGON
# Dimension:     XY
# Bounding box:  xmin: -74.25609 ymin: 40.4961 xmax: -73.70036 ymax: 40.91771
# Geodetic CRS:  NAD83
# # A tibble: 6,981 × 2,332
#    NAME          variable estimate   moe                  geometry `36081014700`
#    <chr>         <chr>       <dbl> <dbl>        <MULTIPOLYGON [°]> <chr>
#  1 Census Tract… populat…     2863   513 (((-73.9137 40.76548, -7… 36081014700
#  2 Census Tract… poverty      2862   513 (((-73.9137 40.76548, -7… 36081014700
#  3 Census Tract… med_inc     71815 18034 (((-73.9137 40.76548, -7… 36081014700
#  4 Census Tract… populat…     3655   529 (((-73.96103 40.59616, -… <NA>
#  5 Census Tract… poverty      3655   529 (((-73.96103 40.59616, -… <NA>
#  6 Census Tract… med_inc     67315 10294 (((-73.96103 40.59616, -… <NA>
#  7 Census Tract… populat…     2450   372 (((-74.02064 40.73039, -… <NA>
#  8 Census Tract… poverty      2126   340 (((-74.02064 40.73039, -… <NA>
#  9 Census Tract… med_inc    237500 65948 (((-74.02064 40.73039, -… <NA>
# 10 Census Tract… populat…     2676   534 (((-73.93345 40.6257, -7… <NA>
# # ℹ 6,971 more rows
# # ℹ 2,326 more variables: `36047058400` <chr>, `36061006900` <chr>,
# #   `36047073000` <chr>, `36047100400` <chr>, `36047055700` <chr>,
# #   `36005022101` <chr>, `36081047000` <chr>, `36047050402` <chr>,
# #   `36047028501` <chr>, `36081017901` <chr>, `36047033900` <chr>,
# #   `36061026700` <chr>, `36047055000` <chr>, `36081047900` <chr>,
# #   `36047064200` <chr>, `36061015501` <chr>, `36005027402` <chr>, …
# # ℹ Use `print(n = ...)` to see more rows, and `colnames()` to see all variable names

# %%
# %%R
#
# nyc_census_data
#
# #download the data as a csv file
# write.csv(nyc_census_data, "census_data1.csv")

# %%
# %%R
# #DOWNLOAD nyc_census_data_wide as a     CSV file
# write.csv(nyc_census_data_wide, "nyc_census_data_wide.csv")

# %%
# %%R
# #define with df the csv 'ToiletWithGeos.csv'
# df <- read_csv('ToiletWithGeos (2).csv')
#
# df
# Out:
# New names:
# • `SUFFIX` -> `SUFFIX...9`
# • `POP100` -> `POP100...10`
# • `GEOID` -> `GEOID...11`
# • `CENTLAT` -> `CENTLAT...12`
# • `BLOCK` -> `BLOCK...13`
# • `AREAWATER` -> `AREAWATER...14`
# • `STATE` -> `STATE...15`
# • `BASENAME` -> `BASENAME...16`
# • `OID` -> `OID...17`
# • `LSADC` -> `LSADC...18`
# • `INTPTLAT` -> `INTPTLAT...19`
# • `FUNCSTAT` -> `FUNCSTAT...20`
# • `NAME` -> `NAME...21`
# • `OBJECTID` -> `OBJECTID...22`
# • `TRACT` -> `TRACT...23`
# • `CENTLON` -> `CENTLON...24`
# • `BLKGRP` -> `BLKGRP...25`
# • `AREALAND` -> `AREALAND...26`
# • `HU100` -> `HU100...27`
# • `INTPTLON` -> `INTPTLON...28`
# • `MTFCC` -> `MTFCC...29`
# • `LWBLKTYP` -> `LWBLKTYP...30`
# • `UR` -> `UR...31`
# • `COUNTY` -> `COUNTY...32`
# • `SUFFIX` -> `SUFFIX...33`
# • `POP100` -> `POP100...34`
# • `GEOID` -> `GEOID...35`
# • `CENTLAT` -> `CENTLAT...36`
# • `BLOCK` -> `BLOCK...37`
# • `AREAWATER` -> `AREAWATER...38`
# • `STATE` -> `STATE...39`
# • `BASENAME` -> `BASENAME...40`
# • `OID` -> `OID...41`
# • `LSADC` -> `LSADC...42`
# • `INTPTLAT` -> `INTPTLAT...43`
# • `FUNCSTAT` -> `FUNCSTAT...44`
# • `NAME` -> `NAME...45`
# • `OBJECTID` -> `OBJECTID...46`
# • `TRACT` -> `TRACT...47`
# • `CENTLON` -> `CENTLON...48`
# • `BLKGRP` -> `BLKGRP...49`
# • `AREALAND` -> `AREALAND...50`
# • `HU100` -> `HU100...51`
# • `INTPTLON` -> `INTPTLON...52`
# • `MTFCC` -> `MTFCC...53`
# • `LWBLKTYP` -> `LWBLKTYP...54`
# • `UR` -> `UR...55`
# • `COUNTY` -> `COUNTY...56`
# • `GEOID` -> `GEOID...57`
# • `STATE` -> `STATE...58`
# • `COUNTY` -> `COUNTY...59`
# • `TRACT` -> `TRACT...60`
# • `BLOCK` -> `BLOCK...61`
# Rows: 616 Columns: 61
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (35): Name, Location, Open Year-Round, Handicap Accessible, Borough, Com...
# dbl (24): Latitude, Longitude, POP100...10, CENTLAT...12, AREAWATER...14, OI...
# lgl  (2): SUFFIX...9, SUFFIX...33
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# # A tibble: 616 × 61
#    Name        Location `Open Year-Round` `Handicap Accessible` Borough Comments
#    <chr>       <chr>    <chr>             <chr>                 <chr>   <chr>
#  1 100% Playg… Glenwoo… Yes               <NA>                  Brookl… <NA>
#  2 174th Stre… East 17… Yes               <NA>                  Bronx   <NA>
#  3 227 Street… Bronx B… Yes               Yes                   Bronx   <NA>
#  4 Abe Lincoln East 13… Yes               <NA>                  Manhat… <NA>
#  5 Abigail Pl… East 15… No                <NA>                  Bronx   <NA>
#  6 Agnes Hayw… East 21… Yes               <NA>                  Bronx   <NA>
#  7 Albemarle … Alberma… Yes               Yes                   Brookl… <NA>
#  8 Albert J. … Adelphi… Yes               Yes                   Brookl… <NA>
#  9 Alexander … Hamilto… Yes               <NA>                  Manhat… <NA>
# 10 Alfred E. … Catheri… Yes               <NA>                  Manhat… <NA>
# # ℹ 606 more rows
# # ℹ 55 more variables: Latitude <dbl>, Longitude <dbl>, SUFFIX...9 <lgl>,
# #   POP100...10 <dbl>, GEOID...11 <chr>, CENTLAT...12 <dbl>, BLOCK...13 <chr>,
# #   AREAWATER...14 <dbl>, STATE...15 <chr>, BASENAME...16 <chr>,
# #   OID...17 <dbl>, LSADC...18 <chr>, INTPTLAT...19 <dbl>, FUNCSTAT...20 <chr>,
# #   NAME...21 <chr>, OBJECTID...22 <dbl>, TRACT...23 <chr>, CENTLON...24 <dbl>,
# #   BLKGRP...25 <dbl>, AREALAND...26 <dbl>, HU100...27 <dbl>, …
# # ℹ Use `print(n = ...)` to see more rows

# %%
# Out:
# NULL
# Además: Warning message:
# Unknown or uninitialised column: `GEOID`.

# %%
# Out:
# NULL
# Además: Warning message:
# Unknown or uninitialised column: `TRACT`.

# %%
# %%R
#
# library(dplyr)
#
# # Print the column names of df and nyc_census_data to verify
# print(colnames(df))
# print(colnames(nyc_census_data))
#
# # Verify the data types of the columns
# print(class(df$GEOID))
# print(class(nyc_census_data$geoid))
#
# # Try converting the data types if necessary
# # df$GEOID <- as.character(df$GEOID)
# # nyc_census_data$geoid <- as.character(nyc_census_data$geoid)
#
# # Attempt the left join operation again
# result <- left_join(df, nyc_census_data, by = c("GEOID" = "geoid"))
# Out:
#  [1] "Name"                "Location"            "Open Year-Round"
#  [4] "Handicap Accessible" "Borough"             "Comments"
#  [7] "Latitude"            "Longitude"           "SUFFIX...9"
# [10] "POP100...10"         "GEOID...11"          "CENTLAT...12"
# [13] "BLOCK...13"          "AREAWATER...14"      "STATE...15"
# [16] "BASENAME...16"       "OID...17"            "LSADC...18"
# [19] "INTPTLAT...19"       "FUNCSTAT...20"       "NAME...21"
# [22] "OBJECTID...22"       "TRACT...23"          "CENTLON...24"
# [25] "BLKGRP...25"         "AREALAND...26"       "HU100...27"
# [28] "INTPTLON...28"       "MTFCC...29"          "LWBLKTYP...30"
# [31] "UR...31"             "COUNTY...32"         "SUFFIX...33"
# [34] "POP100...34"         "GEOID...35"          "CENTLAT...36"
# [37] "BLOCK...37"          "AREAWATER...38"      "STATE...39"
# [40] "BASENAME...40"       "OID...41"            "LSADC...42"
# [43] "INTPTLAT...43"       "FUNCSTAT...44"       "NAME...45"
# [46] "OBJECTID...46"       "TRACT...47"          "CENTLON...48"
# [49] "BLKGRP...49"         "AREALAND...50"       "HU100...51"
# [52] "INTPTLON...52"       "MTFCC...53"          "LWBLKTYP...54"
# [55] "UR...55"             "COUNTY...56"         "GEOID...57"
# [58] "STATE...58"          "COUNTY...59"         "TRACT...60"
# [61] "BLOCK...61"
# [1] "GEOID"    "NAME"     "variable" "estimate" "moe"      "geometry"
# [1] "NULL"
# [1] "NULL"
# Error in `left_join()`:
# ! Join columns in `x` must be present in the data.
# ✖ Problem with `GEOID`.
# Run `rlang::last_trace()` to see where the error occurred.
# Warning message:
# Unknown or uninitialised column: `GEOID`.
# Error in left_join(df, nyc_census_data, by = c(GEOID = "geoid")) :
# ✖ Problem with `GEOID`.
# ---------------------------------------------------------------------------
# RRuntimeError                             Traceback (most recent call last)
# File ~/.pyenv/versions/3.11.6/lib/python3.11/site-packages/rpy2/ipython/rmagic.py:407, in RMagics.eval(self, code)
#     406     r_expr = ri.parse(code)
# --> 407     value, visible = ri.evalr_expr_with_visible(
#     408         r_expr
#     409     )
#     410 except (ri.embedded.RRuntimeError, ValueError) as exception:
#     411     # Otherwise next return seems to have copy of error.
#
# File ~/.pyenv/versions/3.11.6/lib/python3.11/site-packages/rpy2/rinterface.py:196, in evalr_expr_with_visible(expr, envir)
#     195 if error_occured[0]:
# --> 196     raise embedded.RRuntimeError(_rinterface._geterrmessage())
#     197 res = conversion._cdata_to_rinterface(r_res)
#
# RRuntimeError: Error in left_join(df, nyc_census_data, by = c(GEOID = "geoid")) :
# ✖ Problem with `GEOID`.
#
#
# During handling of the above exception, another exception occurred:
#
# RInterpreterError                         Traceback (most recent call last)
# /Users/carlamandiola/Desktop/connect-to-census/merge-with-census.ipynb Cell 22 line 1
# ----> <a href='vscode-notebook-cell:/Users/carlamandiola/Desktop/connect-to-census/merge-with-census.ipynb#X31sZmlsZQ%3D%3D?line=0'>1</a> get_ipython().run_cell_magic('R', '', '\nlibrary(dplyr)\n\n# Print the column names of df and nyc_census_data to verify\nprint(colnames(df))\nprint(colnames(nyc_census_data))\n\n# Verify the data types of the columns\nprint(class(df$GEOID))\nprint(class(nyc_census_data$geoid))\n\n# Try converting the data types if necessary\n# df$GEOID <- as.character(df$GEOID)\n# nyc_census_data$geoid <- as.character(nyc_census_data$geoid)\n\n# Attempt the left join operation again\nresult <- left_join(df, nyc_census_data, by = c("GEOID" = "geoid"))\n')
#
# File ~/.pyenv/versions/3.11.6/lib/python3.11/site-packages/IPython/core/interactiveshell.py:2517, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2515 with self.builtin_trap:
#    2516     args = (magic_arg_s, cell)
# -> 2517     result = fn(*args, **kwargs)
#    2519 # The code below prevents the output from being displayed
#    2520 # when using magics with decorator @output_can_be_silenced
#    2521 # when the last Python token in the expression is a ';'.
#    2522 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File ~/.pyenv/versions/3.11.6/lib/python3.11/site-packages/rpy2/ipython/rmagic.py:984, in RMagics.R(self, line, cell, local_ns)
#     982     if not e.stdout.endswith(e.err):
#     983         print(e.err)
# --> 984     raise e
#     985 finally:
#     986     if self.device in DEVICES_STATIC:
#
# File ~/.pyenv/versions/3.11.6/lib/python3.11/site-packages/rpy2/ipython/rmagic.py:949, in RMagics.R(self, line, cell, local_ns)
#     947         return_output = False
#     948 else:
# --> 949     text_result, result, visible = self.eval(code)
#     950     text_output += text_result
#     951     if visible:
#
# File ~/.pyenv/versions/3.11.6/lib/python3.11/site-packages/rpy2/ipython/rmagic.py:413, in RMagics.eval(self, code)
#     410 except (ri.embedded.RRuntimeError, ValueError) as exception:
#     411     # Otherwise next return seems to have copy of error.
#     412     warning_or_other_msg = self.flush()
# --> 413     raise RInterpreterError(code, str(exception),
#     414                             warning_or_other_msg)
#     415 finally:
#     416     ro._print_deferred_warnings()
#
# RInterpreterError: Failed to parse and evaluate line '\nlibrary(dplyr)\n\n# Print the column names of df and nyc_census_data to verify\nprint(colnames(df))\nprint(colnames(nyc_census_data))\n\n# Verify the data types of the columns\nprint(class(df$GEOID))\nprint(class(nyc_census_data$geoid))\n\n# Try converting the data types if necessary\n# df$GEOID <- as.character(df$GEOID)\n# nyc_census_data$geoid <- as.character(nyc_census_data$geoid)\n\n# Attempt the left join operation again\nresult <- left_join(df, nyc_census_data, by = c("GEOID" = "geoid"))\n'.
# R error message: 'Error in left_join(df, nyc_census_data, by = c(GEOID = "geoid")) : \n✖ Problem with `GEOID`.'
# R stdout:
# Warning message:
# Unknown or uninitialised column: `GEOID`.

# %%
# %%R
# library(readr)
# library(dplyr)
#
# # Read the original ToiletWithGeos (2) CSV file
# toilet_df <- read_csv("ToiletWithGeos (2).csv")
#
# # Modify "COUNTY" column as done previously
# toilet_df <- toilet_df %>%
#   mutate(COUNTY = if_else(COUNTY == 5, sprintf("%03d", COUNTY), sprintf("%02d", COUNTY)))
#
# # Ensure "TRACT" is six digits
# toilet_df <- toilet_df %>%
#   mutate(TRACT = sprintf("%06d", TRACT))
#
# # Create "GEOIDCORRECT" by merging "STATE", "COUNTY", and "TRACT"
# toilet_df <- toilet_df %>%
#   mutate(GEOIDCORRECT = paste0(STATE, COUNTY, TRACT))
#
# # Read the cleaned census_data CSV file (assuming it has been cleaned as described)
# census_df <- read_csv("path/to/your/cleaned_census_data.csv", col_types = cols(
#   GEOIDCORRECT = col_character(),
#   NAME = col_character(),
#   variable = col_character(),
#   estimate = col_double()
# ))
#
# # Merge the two data frames on "GEOIDCORRECT"
# merged_df <- merge(toilet_df, census_df, by = "GEOIDCORRECT")
#
# # Write the merged DataFrame to a new CSV file
# write_csv(merged_df, "Final_Merged_Dataset.csv")
#
# # Note: Replace "path/to/your/" with the actual file paths for your datasets
# Out:
# New names:
# • `SUFFIX` -> `SUFFIX...9`
# • `POP100` -> `POP100...10`
# • `GEOID` -> `GEOID...11`
# • `CENTLAT` -> `CENTLAT...12`
# • `BLOCK` -> `BLOCK...13`
# • `AREAWATER` -> `AREAWATER...14`
# • `STATE` -> `STATE...15`
# • `BASENAME` -> `BASENAME...16`
# • `OID` -> `OID...17`
# • `LSADC` -> `LSADC...18`
# • `INTPTLAT` -> `INTPTLAT...19`
# • `FUNCSTAT` -> `FUNCSTAT...20`
# • `NAME` -> `NAME...21`
# • `OBJECTID` -> `OBJECTID...22`
# • `TRACT` -> `TRACT...23`
# • `CENTLON` -> `CENTLON...24`
# • `BLKGRP` -> `BLKGRP...25`
# • `AREALAND` -> `AREALAND...26`
# • `HU100` -> `HU100...27`
# • `INTPTLON` -> `INTPTLON...28`
# • `MTFCC` -> `MTFCC...29`
# • `LWBLKTYP` -> `LWBLKTYP...30`
# • `UR` -> `UR...31`
# • `COUNTY` -> `COUNTY...32`
# • `SUFFIX` -> `SUFFIX...33`
# • `POP100` -> `POP100...34`
# • `GEOID` -> `GEOID...35`
# • `CENTLAT` -> `CENTLAT...36`
# • `BLOCK` -> `BLOCK...37`
# • `AREAWATER` -> `AREAWATER...38`
# • `STATE` -> `STATE...39`
# • `BASENAME` -> `BASENAME...40`
# • `OID` -> `OID...41`
# • `LSADC` -> `LSADC...42`
# • `INTPTLAT` -> `INTPTLAT...43`
# • `FUNCSTAT` -> `FUNCSTAT...44`
# • `NAME` -> `NAME...45`
# • `OBJECTID` -> `OBJECTID...46`
# • `TRACT` -> `TRACT...47`
# • `CENTLON` -> `CENTLON...48`
# • `BLKGRP` -> `BLKGRP...49`
# • `AREALAND` -> `AREALAND...50`
# • `HU100` -> `HU100...51`
# • `INTPTLON` -> `INTPTLON...52`
# • `MTFCC` -> `MTFCC...53`
# • `LWBLKTYP` -> `LWBLKTYP...54`
# • `UR` -> `UR...55`
# • `COUNTY` -> `COUNTY...56`
# • `GEOID` -> `GEOID...57`
# • `STATE` -> `STATE...58`
# • `COUNTY` -> `COUNTY...59`
# • `TRACT` -> `TRACT...60`
# • `BLOCK` -> `BLOCK...61`
# Rows: 616 Columns: 61
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (35): Name, Location, Open Year-Round, Handicap Accessible, Borough, Com...
# dbl (24): Latitude, Longitude, POP100...10, CENTLAT...12, AREAWATER...14, OI...
# lgl  (2): SUFFIX...9, SUFFIX...33
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Error in `mutate()`:
# ℹ In argument: `COUNTY = if_else(...)`.
# Caused by error:
# ! objeto 'COUNTY' no encontrado
# Run `rlang::last_trace()` to see where the error occurred.
#
# Error in mutate(., COUNTY = if_else(COUNTY == 5, sprintf("%03d", COUNTY),  :
#
# Caused by error:
# ! objeto 'COUNTY' no encontrado
# ---------------------------------------------------------------------------
# RRuntimeError                             Traceback (most recent call last)
# File ~/.pyenv/versions/3.11.6/lib/python3.11/site-packages/rpy2/ipython/rmagic.py:407, in RMagics.eval(self, code)
#     406     r_expr = ri.parse(code)
# --> 407     value, visible = ri.evalr_expr_with_visible(
#     408         r_expr
#     409     )
#     410 except (ri.embedded.RRuntimeError, ValueError) as exception:
#     411     # Otherwise next return seems to have copy of error.
#
# File ~/.pyenv/versions/3.11.6/lib/python3.11/site-packages/rpy2/rinterface.py:196, in evalr_expr_with_visible(expr, envir)
#     195 if error_occured[0]:
# --> 196     raise embedded.RRuntimeError(_rinterface._geterrmessage())
#     197 res = conversion._cdata_to_rinterface(r_res)
#
# RRuntimeError: Error in mutate(., COUNTY = if_else(COUNTY == 5, sprintf("%03d", COUNTY),  :
#
# Caused by error:
# ! objeto 'COUNTY' no encontrado
#
#
# During handling of the above exception, another exception occurred:
#
# RInterpreterError                         Traceback (most recent call last)
# /Users/carlamandiola/Desktop/connect-to-census/merge-with-census.ipynb Cell 29 line 1
# ----> <a href='vscode-notebook-cell:/Users/carlamandiola/Desktop/connect-to-census/merge-with-census.ipynb#X46sZmlsZQ%3D%3D?line=0'>1</a> get_ipython().run_cell_magic('R', '', 'library(readr)\nlibrary(dplyr)\n\n# Read the original ToiletWithGeos (2) CSV file\ntoilet_df <- read_csv("ToiletWithGeos (2).csv")\n\n# Modify "COUNTY" column as done previously\ntoilet_df <- toilet_df %>%\n  mutate(COUNTY = if_else(COUNTY == 5, sprintf("%03d", COUNTY), sprintf("%02d", COUNTY)))\n\n# Ensure "TRACT" is six digits\ntoilet_df <- toilet_df %>%\n  mutate(TRACT = sprintf("%06d", TRACT))\n\n# Create "GEOIDCORRECT" by merging "STATE", "COUNTY", and "TRACT"\ntoilet_df <- toilet_df %>%\n  mutate(GEOIDCORRECT = paste0(STATE, COUNTY, TRACT))\n\n# Read the cleaned census_data CSV file (assuming it has been cleaned as described)\ncensus_df <- read_csv("path/to/your/cleaned_census_data.csv", col_types = cols(\n  GEOIDCORRECT = col_character(),\n  NAME = col_character(),\n  variable = col_character(),\n  estimate = col_double()\n))\n\n# Merge the two data frames on "GEOIDCORRECT"\nmerged_df <- merge(toilet_df, census_df, by = "GEOIDCORRECT")\n\n# Write the merged DataFrame to a new CSV file\nwrite_csv(merged_df, "Final_Merged_Dataset.csv")\n\n# Note: Replace "path/to/your/" with the actual file paths for your datasets\n')
#
# File ~/.pyenv/versions/3.11.6/lib/python3.11/site-packages/IPython/core/interactiveshell.py:2517, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2515 with self.builtin_trap:
#    2516     args = (magic_arg_s, cell)
# -> 2517     result = fn(*args, **kwargs)
#    2519 # The code below prevents the output from being displayed
#    2520 # when using magics with decorator @output_can_be_silenced
#    2521 # when the last Python token in the expression is a ';'.
#    2522 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File ~/.pyenv/versions/3.11.6/lib/python3.11/site-packages/rpy2/ipython/rmagic.py:984, in RMagics.R(self, line, cell, local_ns)
#     982     if not e.stdout.endswith(e.err):
#     983         print(e.err)
# --> 984     raise e
#     985 finally:
#     986     if self.device in DEVICES_STATIC:
#
# File ~/.pyenv/versions/3.11.6/lib/python3.11/site-packages/rpy2/ipython/rmagic.py:949, in RMagics.R(self, line, cell, local_ns)
#     947         return_output = False
#     948 else:
# --> 949     text_result, result, visible = self.eval(code)
#     950     text_output += text_result
#     951     if visible:
#
# File ~/.pyenv/versions/3.11.6/lib/python3.11/site-packages/rpy2/ipython/rmagic.py:413, in RMagics.eval(self, code)
#     410 except (ri.embedded.RRuntimeError, ValueError) as exception:
#     411     # Otherwise next return seems to have copy of error.
#     412     warning_or_other_msg = self.flush()
# --> 413     raise RInterpreterError(code, str(exception),
#     414                             warning_or_other_msg)
#     415 finally:
#     416     ro._print_deferred_warnings()
#
# RInterpreterError: Failed to parse and evaluate line 'library(readr)\nlibrary(dplyr)\n\n# Read the original ToiletWithGeos (2) CSV file\ntoilet_df <- read_csv("ToiletWithGeos (2).csv")\n\n# Modify "COUNTY" column as done previously\ntoilet_df <- toilet_df %>%\n  mutate(COUNTY = if_else(COUNTY == 5, sprintf("%03d", COUNTY), sprintf("%02d", COUNTY)))\n\n# Ensure "TRACT" is six digits\ntoilet_df <- toilet_df %>%\n  mutate(TRACT = sprintf("%06d", TRACT))\n\n# Create "GEOIDCORRECT" by merging "STATE", "COUNTY", and "TRACT"\ntoilet_df <- toilet_df %>%\n  mutate(GEOIDCORRECT = paste0(STATE, COUNTY, TRACT))\n\n# Read the cleaned census_data CSV file (assuming it has been cleaned as described)\ncensus_df <- read_csv("path/to/your/cleaned_census_data.csv", col_types = cols(\n  GEOIDCORRECT = col_character(),\n  NAME = col_character(),\n  variable = col_character(),\n  estimate = col_double()\n))\n\n# Merge the two data frames on "GEOIDCORRECT"\nmerged_df <- merge(toilet_df, census_df, by = "GEOIDCORRECT")\n\n# Write the merged DataFrame to a new CSV file\nwrite_csv(merged_df, "Final_Merged_Dataset.csv")\n\n# Note: Replace "path/to/your/" with the actual file paths for your datasets\n'.
# R error message: 'Error in mutate(., COUNTY = if_else(COUNTY == 5, sprintf("%03d", COUNTY),  : \n  \nCaused by error:\n! objeto \'COUNTY\' no encontrado'
